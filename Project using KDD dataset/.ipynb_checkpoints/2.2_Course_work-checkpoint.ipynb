# %% [markdown]
# # Imported Libraries <a class="anchor" id="libraries"></a>

# %%
#Importing Libraries
import time
import ray
import pandas as pd
import numpy as np
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.neighbors import KNeighborsClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import sklearn
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
# Out:
# 2023-05-26 16:22:23.548656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Function Definations

# %%
def split_dataset(data, tst_size):
    """
    Split the dataset into training and testing sets using speciifed test size and return X_train, X_test, y_train, y_test.

    Args:
        data (pandas.DataFrame): The loaded dataset.
        tst_size: The test size
    Returns:
        tuple: A tuple containing X_train, X_test, y_train, and y_test.
    """

    # Split the data into features (X) and target variable (y)
    X = data.iloc[:, :40]  
    y = data.iloc[:, 40:41]

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=tst_size, random_state=42)

    return X_train, X_test, y_train, y_test

# %%
# Define a function to create Shallow Learning Model (KNN)
def create_shallow_model():
    model = KNeighborsClassifier(n_neighbors=5)
    return model

# %%
#Define a function to call the create_Shallow_model() and train , returning the time and accuracy 
def create_and_train_shallow_model(X_train, y_train, X_test, y_test):
    #List to hold accuracy from KNN model
    knn_acc = []

    # create object of model
    model = create_shallow_model()
    
    #Variable to hold start  time for seq SL 
    SL_seq_start_time = time.time()
    num_epocs = 20
    #compile knn model for a number of iterartions and hold value to a list
    for _ in range(num_epocs):
        model.fit(X_train, y_train)
        SL_acc = accuracy_score(y_train, model.predict(X_train))
        print(f'Epoch {_ + 1} : Accuracy {SL_acc}')
        knn_acc.append(SL_acc)



    final_test_accuracy = knn_acc[-1]
    print("Shallow Learning Model Accuracy (KNN) :", final_test_accuracy)

    #Variable to hold stop  time for seq SL 
    SL_seq_stop_time = time.time()

    #get final run time for SL sequential
    SL_seq_final_time = SL_seq_stop_time - SL_seq_start_time

    #Print runtime for SL sequential 
    print("Shallow Learning Model Sequential Trainig time (KNN) :", SL_seq_final_time,"seconds")
    
    return knn_acc, SL_seq_final_time, model

# %%
# Define a function to create Deep Learning Model (DNN)
# Define the Shallow Learning Model (DNN)
def create_deep_model(num_input, num_output):
    model = keras.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(num_input,)))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(num_output, activation='sigmoid'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
#Define a function to call the create_deep_model() and train , returning the time and accuracy 
def train_deep_model(X_train, y_train, X_test, y_test):
    
    # create object of model
    model = create_deep_model(X_train.shape[1], len(np.unique(y_train)))
    
    #variables to hold accuracies and epoch number
    DL_acc_list = []
    num_epochs = 20
    
    #Variable to hold start  time for seq DL
    DL_seq_start_time = time.time()
    
    #train model x-times
    for _ in range(num_epochs):
        history = model.fit(X_train, y_train, epochs=num_epochs, batch_size=10, verbose=0)
        DL_acc = model.evaluate(X_test, y_test, verbose=0)[1]
        print(f'Epoch {_ + 1} : Accuracy {DL_acc}')
        DL_acc_list.append(DL_acc)
    final_test_accuracy = DL_acc_list[-1]
    print("Deep Learning Model Accuracy (DNN):", final_test_accuracy)
    
    #Variable to hold stop  time for seq DL 
    DL_seq_stop_time = time.time()

    #get final run time for DL sequential
    DL_seq_final_time = DL_seq_stop_time - DL_seq_start_time

    #Print runtime for SL sequential 
    print("Deep Learning Model Sequential Trainig time (DNN) :", DL_seq_final_time,"seconds")
    return DL_acc_list, DL_seq_final_time, model

# %% [markdown]
# # 2.2 Machine learning model creation and training

# %% [markdown]
# ## Loading the data in the combined NSL_DL vector<a class="anchor" id="load_data">

# %%
# Load the combined preprocessed DS_NSL_Final dataset generated and exported to an excel sheet  from task 2.1
dataset = pd.read_excel("DS_NSL_Final.xlsx")

# %% [markdown]
# ### Segmenting Combined NSL-KDD into 30% testing and 70% training, then display the numbers of columns and rows

# %%
X_train, X_test, y_train, y_test = split_dataset(dataset, 0.3)

# %%
# #reshape y_train and y_test
# y_train = y_train.ravel()
# y_test = y_test.ravel()

# Convert y_train DataFrame to numpy array and flatten it
y_train = y_train.values.ravel()

# Convert y_test DataFrame to numpy array and flatten it
y_test = y_test.values.ravel()

# %% [markdown]
# ## Sequential Execution of KNN and DNN

# %% [markdown]
# ### Shallow Learning Model KNN

# %%
knn_acc, SL_seq_final_time, KNN =  create_and_train_shallow_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1 : Accuracy 0.9903286807744259
# Epoch 2 : Accuracy 0.9903286807744259
# Epoch 3 : Accuracy 0.9903286807744259
# Epoch 4 : Accuracy 0.9903286807744259
# Epoch 5 : Accuracy 0.9903286807744259
# Epoch 6 : Accuracy 0.9903286807744259
# Epoch 7 : Accuracy 0.9903286807744259
# Epoch 8 : Accuracy 0.9903286807744259
# Epoch 9 : Accuracy 0.9903286807744259
# Epoch 10 : Accuracy 0.9903286807744259
# Epoch 11 : Accuracy 0.9903286807744259
# Epoch 12 : Accuracy 0.9903286807744259
# Epoch 13 : Accuracy 0.9903286807744259
# Epoch 14 : Accuracy 0.9903286807744259
# Epoch 15 : Accuracy 0.9903286807744259
# Epoch 16 : Accuracy 0.9903286807744259
# Epoch 17 : Accuracy 0.9903286807744259
# Epoch 18 : Accuracy 0.9903286807744259
# Epoch 19 : Accuracy 0.9903286807744259
# Epoch 20 : Accuracy 0.9903286807744259
# Shallow Learning Model Accuracy (KNN) : 0.9903286807744259
# Shallow Learning Model Sequential Trainig time (KNN) : 116.47037100791931 seconds

# %% [markdown]
# ### Deep Learning Model

# %%
#Train dnn
# Train the Deep Learning Model (DNN)
DL_acc_list, DL_seq_final_time, DNN =  train_deep_model(X_train, y_train, X_test, y_test)
# Out:
# 2023-05-26 16:24:57.910737: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1 : Accuracy 0.9528931975364685
# Epoch 2 : Accuracy 0.9553725123405457
# Epoch 3 : Accuracy 0.95638108253479
# Epoch 4 : Accuracy 0.9496574997901917
# Epoch 5 : Accuracy 0.9565491676330566
# Epoch 6 : Accuracy 0.958187997341156
# Epoch 7 : Accuracy 0.9567592740058899
# Epoch 8 : Accuracy 0.9530612826347351
# Epoch 9 : Accuracy 0.957221508026123
# Epoch 10 : Accuracy 0.9588183164596558
# Epoch 11 : Accuracy 0.9577677845954895
# Epoch 12 : Accuracy 0.9578938484191895
# Epoch 13 : Accuracy 0.959028422832489
# Epoch 14 : Accuracy 0.9596167802810669
# Epoch 15 : Accuracy 0.9584821462631226
# Epoch 16 : Accuracy 0.9528931975364685
# Epoch 17 : Accuracy 0.9581039547920227
# Epoch 18 : Accuracy 0.9540278315544128
# Epoch 19 : Accuracy 0.9565491676330566
# Epoch 20 : Accuracy 0.9544480443000793
# Deep Learning Model Accuracy (DNN): 0.9544480443000793
# Deep Learning Model Sequential Trainig time (DNN) : 1811.4923920631409 seconds

# %% [markdown]
# ### Plot the statistics from training iterations of both SL and DL models showing learning accuracies on the y-axis and number of iterations on the x-axis

# %%
# Number of epochs
epochs = range(1, 21)

# Accuracy values for DNN and KNN models

# Plotting the graph
plt.plot(epochs, knn_acc, label='KNN')
plt.plot(epochs, DL_acc_list, label='DNN')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy of DNN and KNN Models')
plt.legend()
plt.show()

# %% [markdown]
# ## Parallel Execution of DNN and KNN

# %%
# # Split data into batches with fixed batch size
# batch_size = len(X_train) // 5  # Adjust the batch size as needed
# x_batches = np.array_split(X_train, batch_size)
# y_batches = np.array_split(y_train, batch_size)

X_train_batches = np.array_split(X_train, 20)
y_train_batches = np.array_split(y_train, 20)

# %%
@ray.remote
def train_shallow_model(X_train, y_train, X_test, y_test):
    # Create and train the Shallow Learning Model (KNN)
    model = KNeighborsClassifier(n_neighbors=5)
    accuracies = []
    for _ in range(20):
        model.fit(X_train, y_train)
        accuracy = accuracy_score(y_test, model.predict(X_test))
        accuracies.append(accuracy)
    return accuracies[-1], model

@ray.remote
def train_deep_model(X_train, y_train, X_test, y_test):
    # Create and train the Deep Learning Model (DNN)
    model = create_deep_model(X_train.shape[1], len(np.unique(y_train)))
    accuracies = []
    for _ in range(20):
        history = model.fit(X_train, y_train, epochs=10, batch_size=10, verbose=0)
        accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
        accuracies.append(accuracy)
    return accuracies[-1], model

# %%
# Train the Deep Learning Model (KNN) in parallel

knn_tasks=[]
knn_results=[]

#measure training time
knn_start_time = time.time()

#train model x-times
for i in range(20):
    knn_tasks.append(train_shallow_model.remote(X_train_batches[i], y_train_batches[i], X_test, y_test))
knn_total_time = time.time() - knn_start_time

#calculate metrics 
for task in knn_tasks:
    accuracy, model = ray.get(task)
    knn_results.append(accuracy)
######################################################################################################################

# Train the Deep Learning Model (DNN) in parallel
dnn_tasks = []
dnn_results = []

#measure training time
dnn_start_time = time.time()

#train model x-times
for i in range(20):
    dnn_tasks.append(train_deep_model.remote(X_train_batches[i], y_train_batches[i], X_test, y_test))
    


#calculate metrics
for task in dnn_tasks:
    accuracy, model = ray.get(task)
    dnn_results.append(accuracy)
dnn_total_time = time.time() - dnn_start_time
# Print the time
print("Total KNN Model Training Time in parallel :", knn_total_time, "seconds")
print("Total DNN Model Training Time in parallel :", dnn_total_time, "seconds")
# Out:
# Total KNN Model Training Time in parallel : 0.9044721126556396 seconds
# Total DNN Model Training Time in parallel : 661.9420831203461 seconds

# %%
# display time taken for both model in sequential and parallel 

# Print the sequential and parallel training times for KNN 
print("Sequential Training Time for KNN:", SL_seq_final_time, "seconds")
print("Parallel Training Time for KNN:", knn_total_time, "seconds")


# Print the sequential and parallel training times for DNN 
print("Sequential Training Time for DNN:", DL_seq_final_time, "seconds")
print("Parallel Training Time for DNN:", dnn_total_time, "seconds")
# Out:
# Sequential Training Time for KNN: 116.47037100791931 seconds
# Parallel Training Time for KNN: 0.9044721126556396 seconds
# Sequential Training Time for DNN: 1811.4923920631409 seconds
# Parallel Training Time for DNN: 661.9420831203461 seconds

# %% [markdown]
# ### Plot graph to show comparison of time taken by SL and DL for sequential training and for parallel training.

# %%
# Sequential training times
sequential_times = [SL_seq_final_time, DL_seq_final_time]

# Parallel training times
parallel_times = [knn_total_time, dnn_total_time]

# Create a bar chart
labels = ['KNN', 'DNN']
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sequential_times, width, label='Sequential')
rects2 = ax.bar(x + width/2, parallel_times, width, label='Parallel')

# Add labels, title, and legend
ax.set_ylabel('Training Time (seconds)')
ax.set_xlabel('Models')
ax.set_title('Training Time Comparison: Sequential vs Parallel')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Display the bar chart
plt.show()

# %% [markdown]
# ### Time Taken for both Models in Sequential and Parallel

# %%
# Create a DataFrame
df_time = pd.DataFrame({
    'KNN': [SL_seq_final_time],
    'DNN': [DL_seq_final_time],
    'KNN_Parallel': [knn_total_time],
    'DNN_Parallel': [dnn_total_time]
})

# Add epoch column
df_time['SN'] = range(1, len(df_time) + 1)

# Set epoch as index
df_time.set_index('SN', inplace=True)

# Apply styling to the DataFrame
styled_df = df_time.style \
    .format('{:.2f}') \
    .background_gradient(cmap='Blues') \
    .set_table_styles([{'selector': 'table', 'props': [('border', '3px solid red')]}])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_fc4a7 table {
#   border: 3px solid red;
# }
# #T_fc4a7_row0_col0, #T_fc4a7_row0_col1, #T_fc4a7_row0_col2, #T_fc4a7_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fc4a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc4a7_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_fc4a7_level0_col1" class="col_heading level0 col1" >DNN</th>
#       <th id="T_fc4a7_level0_col2" class="col_heading level0 col2" >KNN_Parallel</th>
#       <th id="T_fc4a7_level0_col3" class="col_heading level0 col3" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SN</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc4a7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fc4a7_row0_col0" class="data row0 col0" >116.47</td>
#       <td id="T_fc4a7_row0_col1" class="data row0 col1" >1811.49</td>
#       <td id="T_fc4a7_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_fc4a7_row0_col3" class="data row0 col3" >661.94</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Sequential

# %%
# Create a DataFrame
df_seq = pd.DataFrame({
    'KNN': knn_acc,
    'DNN': DL_acc_list
})

# Add epoch column
df_seq['Epoch'] = range(1, len(DL_acc_list) + 1)

# Set epoch as index
df_seq.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_seq = df_seq.style\
    .format('{:.4f}')\
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_seq
# Out:
# <style type="text/css">
# #T_e186c_row0_col0, #T_e186c_row1_col0, #T_e186c_row2_col0, #T_e186c_row3_col0, #T_e186c_row3_col1, #T_e186c_row4_col0, #T_e186c_row5_col0, #T_e186c_row6_col0, #T_e186c_row7_col0, #T_e186c_row8_col0, #T_e186c_row9_col0, #T_e186c_row10_col0, #T_e186c_row11_col0, #T_e186c_row12_col0, #T_e186c_row13_col0, #T_e186c_row14_col0, #T_e186c_row15_col0, #T_e186c_row16_col0, #T_e186c_row17_col0, #T_e186c_row18_col0, #T_e186c_row19_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e186c_row0_col1, #T_e186c_row15_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_e186c_row1_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_e186c_row2_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_e186c_row4_col1, #T_e186c_row18_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_e186c_row5_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_e186c_row6_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_e186c_row7_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_e186c_row8_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_e186c_row9_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_e186c_row10_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_e186c_row11_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_e186c_row12_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_e186c_row13_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e186c_row14_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_e186c_row16_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_e186c_row17_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_e186c_row19_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e186c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e186c_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_e186c_level0_col1" class="col_heading level0 col1" >DNN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e186c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e186c_row0_col0" class="data row0 col0" >0.9903</td>
#       <td id="T_e186c_row0_col1" class="data row0 col1" >0.9529</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e186c_row1_col0" class="data row1 col0" >0.9903</td>
#       <td id="T_e186c_row1_col1" class="data row1 col1" >0.9554</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e186c_row2_col0" class="data row2 col0" >0.9903</td>
#       <td id="T_e186c_row2_col1" class="data row2 col1" >0.9564</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e186c_row3_col0" class="data row3 col0" >0.9903</td>
#       <td id="T_e186c_row3_col1" class="data row3 col1" >0.9497</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e186c_row4_col0" class="data row4 col0" >0.9903</td>
#       <td id="T_e186c_row4_col1" class="data row4 col1" >0.9565</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e186c_row5_col0" class="data row5 col0" >0.9903</td>
#       <td id="T_e186c_row5_col1" class="data row5 col1" >0.9582</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_e186c_row6_col0" class="data row6 col0" >0.9903</td>
#       <td id="T_e186c_row6_col1" class="data row6 col1" >0.9568</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_e186c_row7_col0" class="data row7 col0" >0.9903</td>
#       <td id="T_e186c_row7_col1" class="data row7 col1" >0.9531</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_e186c_row8_col0" class="data row8 col0" >0.9903</td>
#       <td id="T_e186c_row8_col1" class="data row8 col1" >0.9572</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_e186c_row9_col0" class="data row9 col0" >0.9903</td>
#       <td id="T_e186c_row9_col1" class="data row9 col1" >0.9588</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_e186c_row10_col0" class="data row10 col0" >0.9903</td>
#       <td id="T_e186c_row10_col1" class="data row10 col1" >0.9578</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_e186c_row11_col0" class="data row11 col0" >0.9903</td>
#       <td id="T_e186c_row11_col1" class="data row11 col1" >0.9579</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_e186c_row12_col0" class="data row12 col0" >0.9903</td>
#       <td id="T_e186c_row12_col1" class="data row12 col1" >0.9590</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_e186c_row13_col0" class="data row13 col0" >0.9903</td>
#       <td id="T_e186c_row13_col1" class="data row13 col1" >0.9596</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_e186c_row14_col0" class="data row14 col0" >0.9903</td>
#       <td id="T_e186c_row14_col1" class="data row14 col1" >0.9585</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_e186c_row15_col0" class="data row15 col0" >0.9903</td>
#       <td id="T_e186c_row15_col1" class="data row15 col1" >0.9529</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_e186c_row16_col0" class="data row16 col0" >0.9903</td>
#       <td id="T_e186c_row16_col1" class="data row16 col1" >0.9581</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_e186c_row17_col0" class="data row17 col0" >0.9903</td>
#       <td id="T_e186c_row17_col1" class="data row17 col1" >0.9540</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_e186c_row18_col0" class="data row18 col0" >0.9903</td>
#       <td id="T_e186c_row18_col1" class="data row18 col1" >0.9565</td>
#     </tr>
#     <tr>
#       <th id="T_e186c_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_e186c_row19_col0" class="data row19 col0" >0.9903</td>
#       <td id="T_e186c_row19_col1" class="data row19 col1" >0.9544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Parallel

# %%
# Create a DataFrame
df_par = pd.DataFrame({
    'KNN_Parallel': knn_results,
    'DNN_Parallel': dnn_results
})

# Add epoch column
df_par['Epoch'] = range(1, len(knn_results) + 1)

# Set epoch as index
df_par.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_par = df_par.style\
    .format('{:.4f}')\
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_par
# Out:
# <style type="text/css">
# #T_54bc6_row0_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_54bc6_row0_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_54bc6_row1_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_54bc6_row1_col1, #T_54bc6_row9_col1 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_54bc6_row2_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_54bc6_row2_col1, #T_54bc6_row12_col1, #T_54bc6_row18_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_54bc6_row3_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_54bc6_row3_col1, #T_54bc6_row14_col1, #T_54bc6_row17_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_54bc6_row4_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_54bc6_row4_col1, #T_54bc6_row13_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_54bc6_row5_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_54bc6_row5_col1, #T_54bc6_row11_col1, #T_54bc6_row16_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_54bc6_row6_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_54bc6_row6_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_54bc6_row7_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_54bc6_row7_col1 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_54bc6_row8_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_54bc6_row8_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_54bc6_row9_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_54bc6_row10_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_54bc6_row10_col1 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_54bc6_row11_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_54bc6_row12_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_54bc6_row13_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_54bc6_row14_col0, #T_54bc6_row19_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_54bc6_row15_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_54bc6_row15_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_54bc6_row16_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_54bc6_row17_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_54bc6_row18_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_54bc6_row19_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# </style>
# <table id="T_54bc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54bc6_level0_col0" class="col_heading level0 col0" >KNN_Parallel</th>
#       <th id="T_54bc6_level0_col1" class="col_heading level0 col1" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54bc6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_54bc6_row0_col0" class="data row0 col0" >0.9492</td>
#       <td id="T_54bc6_row0_col1" class="data row0 col1" >0.9391</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_54bc6_row1_col0" class="data row1 col0" >0.9429</td>
#       <td id="T_54bc6_row1_col1" class="data row1 col1" >0.9428</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_54bc6_row2_col0" class="data row2 col0" >0.9480</td>
#       <td id="T_54bc6_row2_col1" class="data row2 col1" >0.9455</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_54bc6_row3_col0" class="data row3 col0" >0.9468</td>
#       <td id="T_54bc6_row3_col1" class="data row3 col1" >0.9439</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_54bc6_row4_col0" class="data row4 col0" >0.9456</td>
#       <td id="T_54bc6_row4_col1" class="data row4 col1" >0.7464</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_54bc6_row5_col0" class="data row5 col0" >0.9474</td>
#       <td id="T_54bc6_row5_col1" class="data row5 col1" >0.9440</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_54bc6_row6_col0" class="data row6 col0" >0.9498</td>
#       <td id="T_54bc6_row6_col1" class="data row6 col1" >0.9401</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_54bc6_row7_col0" class="data row7 col0" >0.9448</td>
#       <td id="T_54bc6_row7_col1" class="data row7 col1" >0.9393</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_54bc6_row8_col0" class="data row8 col0" >0.9487</td>
#       <td id="T_54bc6_row8_col1" class="data row8 col1" >0.9368</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_54bc6_row9_col0" class="data row9 col0" >0.9453</td>
#       <td id="T_54bc6_row9_col1" class="data row9 col1" >0.9430</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_54bc6_row10_col0" class="data row10 col0" >0.9427</td>
#       <td id="T_54bc6_row10_col1" class="data row10 col1" >0.9338</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_54bc6_row11_col0" class="data row11 col0" >0.9508</td>
#       <td id="T_54bc6_row11_col1" class="data row11 col1" >0.9440</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_54bc6_row12_col0" class="data row12 col0" >0.9451</td>
#       <td id="T_54bc6_row12_col1" class="data row12 col1" >0.9454</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_54bc6_row13_col0" class="data row13 col0" >0.9399</td>
#       <td id="T_54bc6_row13_col1" class="data row13 col1" >0.9457</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_54bc6_row14_col0" class="data row14 col0" >0.9536</td>
#       <td id="T_54bc6_row14_col1" class="data row14 col1" >0.9436</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_54bc6_row15_col0" class="data row15 col0" >0.9492</td>
#       <td id="T_54bc6_row15_col1" class="data row15 col1" >0.9418</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_54bc6_row16_col0" class="data row16 col0" >0.9497</td>
#       <td id="T_54bc6_row16_col1" class="data row16 col1" >0.9446</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_54bc6_row17_col0" class="data row17 col0" >0.9500</td>
#       <td id="T_54bc6_row17_col1" class="data row17 col1" >0.9437</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_54bc6_row18_col0" class="data row18 col0" >0.9491</td>
#       <td id="T_54bc6_row18_col1" class="data row18 col1" >0.9449</td>
#     </tr>
#     <tr>
#       <th id="T_54bc6_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_54bc6_row19_col0" class="data row19 col0" >0.9439</td>
#       <td id="T_54bc6_row19_col1" class="data row19 col1" >0.9537</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Sequence and Parallel

# %%
# Create a DataFrame
df_combined = pd.DataFrame({
    'KNN': knn_acc,
    'DNN': DL_acc_list,
    'KNN_Parallel': knn_results,
    'DNN_Parallel': dnn_results
})

# Add epoch column
df_combined['Epoch'] = range(1, len(knn_acc) + 1)

# Set epoch as index
df_combined.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_combined = df_combined.style \
    .format('{:.4f}') \
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_combined
# Out:
# <style type="text/css">
# #T_2b706_row0_col0, #T_2b706_row1_col0, #T_2b706_row2_col0, #T_2b706_row3_col0, #T_2b706_row3_col1, #T_2b706_row4_col0, #T_2b706_row4_col3, #T_2b706_row5_col0, #T_2b706_row6_col0, #T_2b706_row7_col0, #T_2b706_row8_col0, #T_2b706_row9_col0, #T_2b706_row10_col0, #T_2b706_row11_col0, #T_2b706_row12_col0, #T_2b706_row13_col0, #T_2b706_row13_col2, #T_2b706_row14_col0, #T_2b706_row15_col0, #T_2b706_row16_col0, #T_2b706_row17_col0, #T_2b706_row18_col0, #T_2b706_row19_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2b706_row0_col1, #T_2b706_row15_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_2b706_row0_col2 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_2b706_row0_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_2b706_row1_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_2b706_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_2b706_row1_col3, #T_2b706_row9_col3 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_2b706_row2_col1, #T_2b706_row18_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_2b706_row2_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_2b706_row2_col3, #T_2b706_row12_col3, #T_2b706_row18_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_2b706_row3_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_2b706_row3_col3, #T_2b706_row14_col3, #T_2b706_row17_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_2b706_row4_col1, #T_2b706_row18_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_2b706_row4_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_2b706_row5_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_2b706_row5_col2 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_2b706_row5_col3, #T_2b706_row11_col3, #T_2b706_row16_col3 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_2b706_row6_col1, #T_2b706_row16_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_2b706_row6_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_2b706_row6_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_2b706_row7_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_2b706_row7_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_2b706_row7_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_2b706_row8_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_2b706_row8_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_2b706_row8_col3, #T_2b706_row9_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_2b706_row9_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_2b706_row10_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_2b706_row10_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_2b706_row10_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_2b706_row11_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_2b706_row11_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_2b706_row12_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_2b706_row12_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_2b706_row13_col1, #T_2b706_row14_col2, #T_2b706_row19_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2b706_row13_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_2b706_row14_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_2b706_row15_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_2b706_row15_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_2b706_row16_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_2b706_row17_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_2b706_row17_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_2b706_row19_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_2b706_row19_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# </style>
# <table id="T_2b706">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b706_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_2b706_level0_col1" class="col_heading level0 col1" >DNN</th>
#       <th id="T_2b706_level0_col2" class="col_heading level0 col2" >KNN_Parallel</th>
#       <th id="T_2b706_level0_col3" class="col_heading level0 col3" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b706_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2b706_row0_col0" class="data row0 col0" >0.9903</td>
#       <td id="T_2b706_row0_col1" class="data row0 col1" >0.9529</td>
#       <td id="T_2b706_row0_col2" class="data row0 col2" >0.9492</td>
#       <td id="T_2b706_row0_col3" class="data row0 col3" >0.9391</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2b706_row1_col0" class="data row1 col0" >0.9903</td>
#       <td id="T_2b706_row1_col1" class="data row1 col1" >0.9554</td>
#       <td id="T_2b706_row1_col2" class="data row1 col2" >0.9429</td>
#       <td id="T_2b706_row1_col3" class="data row1 col3" >0.9428</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2b706_row2_col0" class="data row2 col0" >0.9903</td>
#       <td id="T_2b706_row2_col1" class="data row2 col1" >0.9564</td>
#       <td id="T_2b706_row2_col2" class="data row2 col2" >0.9480</td>
#       <td id="T_2b706_row2_col3" class="data row2 col3" >0.9455</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2b706_row3_col0" class="data row3 col0" >0.9903</td>
#       <td id="T_2b706_row3_col1" class="data row3 col1" >0.9497</td>
#       <td id="T_2b706_row3_col2" class="data row3 col2" >0.9468</td>
#       <td id="T_2b706_row3_col3" class="data row3 col3" >0.9439</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2b706_row4_col0" class="data row4 col0" >0.9903</td>
#       <td id="T_2b706_row4_col1" class="data row4 col1" >0.9565</td>
#       <td id="T_2b706_row4_col2" class="data row4 col2" >0.9456</td>
#       <td id="T_2b706_row4_col3" class="data row4 col3" >0.7464</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2b706_row5_col0" class="data row5 col0" >0.9903</td>
#       <td id="T_2b706_row5_col1" class="data row5 col1" >0.9582</td>
#       <td id="T_2b706_row5_col2" class="data row5 col2" >0.9474</td>
#       <td id="T_2b706_row5_col3" class="data row5 col3" >0.9440</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2b706_row6_col0" class="data row6 col0" >0.9903</td>
#       <td id="T_2b706_row6_col1" class="data row6 col1" >0.9568</td>
#       <td id="T_2b706_row6_col2" class="data row6 col2" >0.9498</td>
#       <td id="T_2b706_row6_col3" class="data row6 col3" >0.9401</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_2b706_row7_col0" class="data row7 col0" >0.9903</td>
#       <td id="T_2b706_row7_col1" class="data row7 col1" >0.9531</td>
#       <td id="T_2b706_row7_col2" class="data row7 col2" >0.9448</td>
#       <td id="T_2b706_row7_col3" class="data row7 col3" >0.9393</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_2b706_row8_col0" class="data row8 col0" >0.9903</td>
#       <td id="T_2b706_row8_col1" class="data row8 col1" >0.9572</td>
#       <td id="T_2b706_row8_col2" class="data row8 col2" >0.9487</td>
#       <td id="T_2b706_row8_col3" class="data row8 col3" >0.9368</td>
#     </tr>
#     <tr>
#       <th id="T_2b706_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_2b706_row9_col0" cla

# %%
# display time taken for both model in sequential and parallel 

# Print the sequential and parallel training times for KNN 
print("Sequential Training Time for KNN:", SL_seq_final_time, "seconds")
print("Parallel Training Time for KNN:", knn_total_time, "seconds")


# Print the sequential and parallel training times for DNN 
print("Sequential Training Time for DNN:", DL_seq_final_time, "seconds")
print("Parallel Training Time for DNN:", dnn_total_time, "seconds")
# Out:
# Sequential Training Time for KNN: 116.47037100791931 seconds
# Parallel Training Time for KNN: 0.9044721126556396 seconds
# Sequential Training Time for DNN: 1811.4923920631409 seconds
# Parallel Training Time for DNN: 661.9420831203461 seconds
