# %% [markdown]
# # Imported Libraries <a class="anchor" id="libraries"></a>

# %%
#Importing Libraries
import time
import ray
import pandas as pd
import numpy as np
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.neighbors import KNeighborsClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import sklearn
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# # Function Definations

# %%
def split_dataset(data, tst_size):
    """
    Split the dataset into training and testing sets using speciifed test size and return X_train, X_test, y_train, y_test.

    Args:
        data (pandas.DataFrame): The loaded dataset.
        tst_size: The test size
    Returns:
        tuple: A tuple containing X_train, X_test, y_train, and y_test.
    """

    # Split the data into features (X) and target variable (y)
    X = data.iloc[:, :40]  
    y = data.iloc[:, 40:41]

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=tst_size, random_state=42)

    return X_train, X_test, y_train, y_test

# %%
# Define a function to create Shallow Learning Model (KNN)
def create_shallow_model():
    model = KNeighborsClassifier(n_neighbors=5)
    return model

# %%
#Define a function to call the create_Shallow_model() and train , returning the time and accuracy 
def create_and_train_shallow_model(X_train, y_train, X_test, y_test):
    #List to hold accuracy from KNN model
    knn_acc = []

    # create object of model
    model = create_shallow_model()
    
    #Variable to hold start  time for seq SL 
    SL_seq_start_time = time.time()
    num_epocs = 20
    #compile knn model for a number of iterartions and hold value to a list
    for _ in range(num_epocs):
        model.fit(X_train, y_train)
        SL_acc = accuracy_score(y_train, model.predict(X_train))
        print(f'Epoch {_ + 1} : Accuracy {SL_acc}')
        knn_acc.append(SL_acc)



    final_test_accuracy = knn_acc[-1]
    print("Shallow Learning Model Accuracy (KNN) :", final_test_accuracy)

    #Variable to hold stop  time for seq SL 
    SL_seq_stop_time = time.time()

    #get final run time for SL sequential
    SL_seq_final_time = SL_seq_stop_time - SL_seq_start_time

    #Print runtime for SL sequential 
    print("Shallow Learning Model Sequential Trainig time (KNN) :", SL_seq_final_time,"seconds")
    
    return knn_acc, SL_seq_final_time, model

# %%
# Define a function to create Deep Learning Model (DNN)
# Define the Shallow Learning Model (DNN)
def create_deep_model(num_input, num_output):
    model = keras.Sequential()
    model.add(layers.Dense(64, activation='relu', input_shape=(num_input,)))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(16, activation='relu'))
    model.add(layers.Dense(num_output, activation='sigmoid'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
#Define a function to call the create_deep_model() and train , returning the time and accuracy 
def train_deep_model(X_train, y_train, X_test, y_test):
    # create object of model
    model = create_deep_model(X_train.shape[1], len(np.unique(y_train)))
    DL_acc_list = []
    #Variable to hold start  time for seq DL
    
    DL_seq_start_time = time.time()
    num_epochs = 20
    for _ in range(num_epochs):
        history = model.fit(X_train, y_train, epochs=num_epochs, batch_size=10, verbose=0)
        DL_acc = model.evaluate(X_test, y_test, verbose=0)[1]
        print(f'Epoch {_ + 1} : Accuracy {DL_acc}')
        DL_acc_list.append(DL_acc)
    final_test_accuracy = DL_acc_list[-1]
    print("Deep Learning Model Accuracy (DNN):", final_test_accuracy)
    
    #Variable to hold stop  time for seq DL 
    DL_seq_stop_time = time.time()

    #get final run time for DL sequential
    DL_seq_final_time = DL_seq_stop_time - DL_seq_start_time

    #Print runtime for SL sequential 
    print("Deep Learning Model Sequential Trainig time (DNN) :", DL_seq_final_time,"seconds")
    return DL_acc_list, DL_seq_final_time, model

# %% [markdown]
# # 2.2 Machine learning model creation and training

# %% [markdown]
# ## Loading the data in the combined NSL_DL vector<a class="anchor" id="load_data">

# %%
# Load the combined preprocessed DS_NSL_Final dataset generated and exported to an excel sheet  from task 2.1
dataset = pd.read_excel("DS_NSL_Final.xlsx")

# %% [markdown]
# ### Segmenting Combined NSL-KDD into 30% testing and 70% training, then display the numbers of columns and rows

# %%
X_train, X_test, y_train, y_test = split_dataset(dataset, 0.3)

# %%
# #reshape y_train and y_test
# y_train = y_train.ravel()
# y_test = y_test.ravel()

# Convert y_train DataFrame to numpy array and flatten it
y_train = y_train.values.ravel()

# Convert y_test DataFrame to numpy array and flatten it
y_test = y_test.values.ravel()

# %% [markdown]
# ## Sequential Execution of KNN and DNN

# %% [markdown]
# ### Shallow Learning Model KNN

# %%
knn_acc, SL_seq_final_time, KNN =  create_and_train_shallow_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1 : Accuracy 0.9903286807744259
# Epoch 2 : Accuracy 0.9903286807744259
# Epoch 3 : Accuracy 0.9903286807744259
# Epoch 4 : Accuracy 0.9903286807744259
# Epoch 5 : Accuracy 0.9903286807744259
# Epoch 6 : Accuracy 0.9903286807744259
# Epoch 7 : Accuracy 0.9903286807744259
# Epoch 8 : Accuracy 0.9903286807744259
# Epoch 9 : Accuracy 0.9903286807744259
# Epoch 10 : Accuracy 0.9903286807744259
# Epoch 11 : Accuracy 0.9903286807744259
# Epoch 12 : Accuracy 0.9903286807744259
# Epoch 13 : Accuracy 0.9903286807744259
# Epoch 14 : Accuracy 0.9903286807744259
# Epoch 15 : Accuracy 0.9903286807744259
# Epoch 16 : Accuracy 0.9903286807744259
# Epoch 17 : Accuracy 0.9903286807744259
# Epoch 18 : Accuracy 0.9903286807744259
# Epoch 19 : Accuracy 0.9903286807744259
# Epoch 20 : Accuracy 0.9903286807744259
# Shallow Learning Model Accuracy (KNN) : 0.9903286807744259
# Shallow Learning Model Sequential Trainig time (KNN) : 113.9095401763916 seconds

# %% [markdown]
# ### Deep Learning Model

# %%
#Train dnn
# Train the Deep Learning Model (DNN)
DL_acc_list, DL_seq_final_time, DNN =  train_deep_model(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1 : Accuracy 0.9525150060653687
# Epoch 2 : Accuracy 0.9511283040046692
# Epoch 3 : Accuracy 0.9570534229278564
# Epoch 4 : Accuracy 0.9662562608718872
# Epoch 5 : Accuracy 0.9588183164596558
# Epoch 6 : Accuracy 0.9597428441047668
# Epoch 7 : Accuracy 0.9575576782226562
# Epoch 8 : Accuracy 0.9594066739082336
# Epoch 9 : Accuracy 0.9525150060653687
# Epoch 10 : Accuracy 0.9519267082214355
# Epoch 11 : Accuracy 0.9538177251815796
# Epoch 12 : Accuracy 0.9532294273376465
# Epoch 13 : Accuracy 0.9515485167503357
# Epoch 14 : Accuracy 0.9513384103775024
# Epoch 15 : Accuracy 0.953523576259613
# Epoch 16 : Accuracy 0.9544480443000793
# Epoch 17 : Accuracy 0.9549522995948792
# Epoch 18 : Accuracy 0.9539437890052795
# Epoch 19 : Accuracy 0.9530612826347351
# Epoch 20 : Accuracy 0.9536916613578796
# Deep Learning Model Accuracy (DNN): 0.9536916613578796
# Deep Learning Model Sequential Trainig time (DNN) : 1761.6034569740295 seconds

# %% [markdown]
# ### Plot the statistics from training iterations of both SL and DL models showing learning accuracies on the y-axis and number of iterations on the x-axis

# %%
# Number of epochs
epochs = range(1, 21)

# Accuracy values for DNN and KNN models

# Plotting the graph
plt.plot(epochs, knn_acc, label='KNN')
plt.plot(epochs, DL_acc_list, label='DNN')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy of DNN and KNN Models')
plt.legend()
plt.show()

# %% [markdown]
# ## Parallel Execution of DNN and KNN

# %%
# # Split data into batches with fixed batch size
# batch_size = len(X_train) // 5  # Adjust the batch size as needed
# x_batches = np.array_split(X_train, batch_size)
# y_batches = np.array_split(y_train, batch_size)

X_train_batches = np.array_split(X_train, 20)
y_train_batches = np.array_split(y_train, 20)

# %%
@ray.remote
def train_shallow_model(X_train, y_train, X_test, y_test):
    # Create and train the Shallow Learning Model (KNN)
    model = KNeighborsClassifier(n_neighbors=5)
    accuracies = []
    for _ in range(20):
        model.fit(X_train, y_train)
        accuracy = accuracy_score(y_test, model.predict(X_test))
        accuracies.append(accuracy)
    return accuracies[-1], model

@ray.remote
def train_deep_model(X_train, y_train, X_test, y_test):
    # Create and train the Deep Learning Model (DNN)
    model = create_deep_model(X_train.shape[1], len(np.unique(y_train)))
    accuracies = []
    for _ in range(20):
        history = model.fit(X_train, y_train, epochs=10, batch_size=10, verbose=0)
        accuracy = model.evaluate(X_test, y_test, verbose=0)[1]
        accuracies.append(accuracy)
    return accuracies[-1], model

# %%
knn_tasks=[]
knn_results=[]
knn_start_time = time.time()
for i in range(20):
    knn_tasks.append(train_shallow_model.remote(X_train_batches[i], y_train_batches[i], X_test, y_test))

for task in knn_tasks:
    accuracy, model = ray.get(task)
    knn_results.append(accuracy)
knn_total_time = time.time() - knn_start_time

# Train the Deep Learning Model (DNN) in parallel
dnn_tasks = []
dnn_results = []
dnn_start_time = time.time()
for i in range(20):
    dnn_tasks.append(train_deep_model.remote(X_train_batches[i], y_train_batches[i], X_test, y_test))

for task in dnn_tasks:
    accuracy, model = ray.get(task)
    dnn_results.append(accuracy)
dnn_total_time = time.time() - dnn_start_time

# Print the results
print("KNN Model Accuracies:", knn_results)
print("Total KNN Model Training Time:", knn_total_time, "seconds")
print("DNN Model Accuracies:", dnn_results)
print("Total DNN Model Training Time:", dnn_total_time, "seconds")
# Out:
# (train_shallow_model pid=31879) 2023-05-25 19:59:15.886374: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA [repeated 5x across cluster]
# (train_shallow_model pid=31879) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags. [repeated 5x across cluster]
# (train_deep_model pid=31876) 2023-05-25 19:59:26.352634: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA [repeated 3x across cluster]
# (train_deep_model pid=31876) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags. [repeated 3x across cluster]
# KNN Model Accuracies: [0.9492372988191788, 0.9429339832752027, 0.9479766357103837, 0.946842038912468, 0.9456233979072992, 0.947430348363239, 0.9497835861663235, 0.9447829558347691, 0.9486910114720343, 0.9452872210782872, 0.9426818506534437, 0.9507500945497331, 0.9451191326637811, 0.9398663697104677, 0.9536075975963356, 0.9491532546119259, 0.949657519855444, 0.949993696684456, 0.9491112325082993, 0.9439004916586125]
# Total KNN Model Training Time: 109.97526001930237 seconds
# DNN Model Accuracies: [0.9438584446907043, 0.9434802532196045, 0.9360003471374512, 0.9341513514518738, 0.9411690831184387, 0.9436483383178711, 0.9452872276306152, 0.9402445554733276, 0.9161238670349121, 0.9207883477210999, 0.9443207383155823, 0.944236695766449, 0.941379189491272, 0.9420515298843384, 0.9352859854698181, 0.9524309635162354, 0.9464218020439148, 0.9444888234138489, 0.9309576749801636, 0.9443627595901489]
# Total DNN Model Training Time: 563.4362001419067 seconds

# %%
# display time taken for both model in sequential and parallel 

# Print the sequential and parallel training times for KNN 
print("Sequential Training Time for KNN:", SL_seq_final_time, "seconds")
print("Parallel Training Time for KNN:", knn_total_time, "seconds")


# Print the sequential and parallel training times for DNN 
print("Sequential Training Time for DNN:", DL_seq_final_time, "seconds")
print("Parallel Training Time for DNN:", dnn_total_time, "seconds")
# Out:
# Sequential Training Time for KNN: 113.9095401763916 seconds
# Parallel Training Time for KNN: 109.97526001930237 seconds
# Sequential Training Time for DNN: 1761.6034569740295 seconds
# Parallel Training Time for DNN: 563.4362001419067 seconds

# %% [markdown]
# ### Plot graph to show comparison of time taken by SL and DL for sequential training and for parallel training.

# %%
# Sequential training times
sequential_times = [SL_seq_final_time, DL_seq_final_time]

# Parallel training times
parallel_times = [knn_total_time, dnn_total_time]

# Create a bar chart
labels = ['KNN', 'DNN']
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sequential_times, width, label='Sequential')
rects2 = ax.bar(x + width/2, parallel_times, width, label='Parallel')

# Add labels, title, and legend
ax.set_ylabel('Training Time (seconds)')
ax.set_xlabel('Models')
ax.set_title('Training Time Comparison: Sequential vs Parallel')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Display the bar chart
plt.show()

# %% [markdown]
# ### Time Taken for both Models in Sequential and Parallel

# %%
# Create a DataFrame
df_time = pd.DataFrame({
    'KNN': [SL_seq_final_time],
    'DNN': [DL_seq_final_time],
    'KNN_Parallel': [knn_total_time],
    'DNN_Parallel': [dnn_total_time]
})

# Add epoch column
df_time['SN'] = range(1, len(df_time) + 1)

# Set epoch as index
df_time.set_index('SN', inplace=True)

# Apply styling to the DataFrame
styled_df = df_time.style \
    .format('{:.2f}') \
    .background_gradient(cmap='Blues') \
    .set_table_styles([{'selector': 'table', 'props': [('border', '3px solid red')]}])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_20064 table {
#   border: 3px solid red;
# }
# #T_20064_row0_col0, #T_20064_row0_col1, #T_20064_row0_col2, #T_20064_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_20064">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20064_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_20064_level0_col1" class="col_heading level0 col1" >DNN</th>
#       <th id="T_20064_level0_col2" class="col_heading level0 col2" >KNN_Parallel</th>
#       <th id="T_20064_level0_col3" class="col_heading level0 col3" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SN</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20064_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_20064_row0_col0" class="data row0 col0" >113.91</td>
#       <td id="T_20064_row0_col1" class="data row0 col1" >1761.60</td>
#       <td id="T_20064_row0_col2" class="data row0 col2" >109.98</td>
#       <td id="T_20064_row0_col3" class="data row0 col3" >563.44</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Sequential

# %%
# Create a DataFrame
df_seq = pd.DataFrame({
    'KNN': knn_accuracies,
    'DNN': dnn_accuracies
})

# Add epoch column
df_seq['Epoch'] = range(1, len(knn_accuracies) + 1)

# Set epoch as index
df_seq.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_seq = df_seq.style\
    .format('{:.4f}')\
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_seq
# Out:
# <style type="text/css">
# #T_80176_row0_col0, #T_80176_row1_col0, #T_80176_row1_col1, #T_80176_row2_col0, #T_80176_row3_col0, #T_80176_row4_col0, #T_80176_row5_col0, #T_80176_row6_col0, #T_80176_row7_col0, #T_80176_row8_col0, #T_80176_row9_col0, #T_80176_row10_col0, #T_80176_row11_col0, #T_80176_row12_col0, #T_80176_row13_col0, #T_80176_row14_col0, #T_80176_row15_col0, #T_80176_row16_col0, #T_80176_row17_col0, #T_80176_row18_col0, #T_80176_row19_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_80176_row0_col1, #T_80176_row8_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_80176_row2_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_80176_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_80176_row4_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_80176_row5_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_80176_row6_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_80176_row7_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_80176_row9_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_80176_row10_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_80176_row11_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_80176_row12_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_80176_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_80176_row14_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_80176_row15_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_80176_row16_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_80176_row17_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_80176_row18_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_80176_row19_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# </style>
# <table id="T_80176">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80176_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_80176_level0_col1" class="col_heading level0 col1" >DNN</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80176_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_80176_row0_col0" class="data row0 col0" >0.9903</td>
#       <td id="T_80176_row0_col1" class="data row0 col1" >0.9525</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_80176_row1_col0" class="data row1 col0" >0.9903</td>
#       <td id="T_80176_row1_col1" class="data row1 col1" >0.9511</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_80176_row2_col0" class="data row2 col0" >0.9903</td>
#       <td id="T_80176_row2_col1" class="data row2 col1" >0.9571</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_80176_row3_col0" class="data row3 col0" >0.9903</td>
#       <td id="T_80176_row3_col1" class="data row3 col1" >0.9663</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_80176_row4_col0" class="data row4 col0" >0.9903</td>
#       <td id="T_80176_row4_col1" class="data row4 col1" >0.9588</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_80176_row5_col0" class="data row5 col0" >0.9903</td>
#       <td id="T_80176_row5_col1" class="data row5 col1" >0.9597</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_80176_row6_col0" class="data row6 col0" >0.9903</td>
#       <td id="T_80176_row6_col1" class="data row6 col1" >0.9576</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_80176_row7_col0" class="data row7 col0" >0.9903</td>
#       <td id="T_80176_row7_col1" class="data row7 col1" >0.9594</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_80176_row8_col0" class="data row8 col0" >0.9903</td>
#       <td id="T_80176_row8_col1" class="data row8 col1" >0.9525</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_80176_row9_col0" class="data row9 col0" >0.9903</td>
#       <td id="T_80176_row9_col1" class="data row9 col1" >0.9519</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_80176_row10_col0" class="data row10 col0" >0.9903</td>
#       <td id="T_80176_row10_col1" class="data row10 col1" >0.9538</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_80176_row11_col0" class="data row11 col0" >0.9903</td>
#       <td id="T_80176_row11_col1" class="data row11 col1" >0.9532</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_80176_row12_col0" class="data row12 col0" >0.9903</td>
#       <td id="T_80176_row12_col1" class="data row12 col1" >0.9515</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_80176_row13_col0" class="data row13 col0" >0.9903</td>
#       <td id="T_80176_row13_col1" class="data row13 col1" >0.9513</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_80176_row14_col0" class="data row14 col0" >0.9903</td>
#       <td id="T_80176_row14_col1" class="data row14 col1" >0.9535</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_80176_row15_col0" class="data row15 col0" >0.9903</td>
#       <td id="T_80176_row15_col1" class="data row15 col1" >0.9544</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_80176_row16_col0" class="data row16 col0" >0.9903</td>
#       <td id="T_80176_row16_col1" class="data row16 col1" >0.9550</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_80176_row17_col0" class="data row17 col0" >0.9903</td>
#       <td id="T_80176_row17_col1" class="data row17 col1" >0.9539</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_80176_row18_col0" class="data row18 col0" >0.9903</td>
#       <td id="T_80176_row18_col1" class="data row18 col1" >0.9531</td>
#     </tr>
#     <tr>
#       <th id="T_80176_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_80176_row19_col0" class="data row19 col0" >0.9903</td>
#       <td id="T_80176_row19_col1" class="data row19 col1" >0.9537</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Parallel

# %%
# Create a DataFrame
df_par = pd.DataFrame({
    'KNN_Parallel': knn_results,
    'DNN_Parallel': dnn_results
})

# Add epoch column
df_par['Epoch'] = range(1, len(knn_results) + 1)

# Set epoch as index
df_par.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_par = df_par.style\
    .format('{:.4f}')\
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_par
# Out:
# <style type="text/css">
# #T_23759_row0_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_23759_row0_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_23759_row1_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_23759_row1_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_23759_row2_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_23759_row2_col1, #T_23759_row5_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_23759_row3_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_23759_row3_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_23759_row4_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_23759_row4_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_23759_row5_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_23759_row6_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_23759_row6_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_23759_row7_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_23759_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_23759_row8_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_23759_row8_col1, #T_23759_row13_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_23759_row9_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_23759_row9_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_23759_row10_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_23759_row10_col1, #T_23759_row11_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_23759_row11_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_23759_row12_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_23759_row12_col1 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_23759_row13_col1, #T_23759_row16_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_23759_row14_col0, #T_23759_row15_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_23759_row14_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_23759_row15_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_23759_row16_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_23759_row17_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_23759_row17_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_23759_row18_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_23759_row18_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_23759_row19_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_23759_row19_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23759">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23759_level0_col0" class="col_heading level0 col0" >KNN_Parallel</th>
#       <th id="T_23759_level0_col1" class="col_heading level0 col1" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23759_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_23759_row0_col0" class="data row0 col0" >0.9492</td>
#       <td id="T_23759_row0_col1" class="data row0 col1" >0.9439</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_23759_row1_col0" class="data row1 col0" >0.9429</td>
#       <td id="T_23759_row1_col1" class="data row1 col1" >0.9435</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_23759_row2_col0" class="data row2 col0" >0.9480</td>
#       <td id="T_23759_row2_col1" class="data row2 col1" >0.9360</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_23759_row3_col0" class="data row3 col0" >0.9468</td>
#       <td id="T_23759_row3_col1" class="data row3 col1" >0.9342</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_23759_row4_col0" class="data row4 col0" >0.9456</td>
#       <td id="T_23759_row4_col1" class="data row4 col1" >0.9412</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_23759_row5_col0" class="data row5 col0" >0.9474</td>
#       <td id="T_23759_row5_col1" class="data row5 col1" >0.9436</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_23759_row6_col0" class="data row6 col0" >0.9498</td>
#       <td id="T_23759_row6_col1" class="data row6 col1" >0.9453</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_23759_row7_col0" class="data row7 col0" >0.9448</td>
#       <td id="T_23759_row7_col1" class="data row7 col1" >0.9402</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_23759_row8_col0" class="data row8 col0" >0.9487</td>
#       <td id="T_23759_row8_col1" class="data row8 col1" >0.9161</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_23759_row9_col0" class="data row9 col0" >0.9453</td>
#       <td id="T_23759_row9_col1" class="data row9 col1" >0.9208</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_23759_row10_col0" class="data row10 col0" >0.9427</td>
#       <td id="T_23759_row10_col1" class="data row10 col1" >0.9443</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_23759_row11_col0" class="data row11 col0" >0.9508</td>
#       <td id="T_23759_row11_col1" class="data row11 col1" >0.9442</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_23759_row12_col0" class="data row12 col0" >0.9451</td>
#       <td id="T_23759_row12_col1" class="data row12 col1" >0.9414</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_23759_row13_col0" class="data row13 col0" >0.9399</td>
#       <td id="T_23759_row13_col1" class="data row13 col1" >0.9421</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_23759_row14_col0" class="data row14 col0" >0.9536</td>
#       <td id="T_23759_row14_col1" class="data row14 col1" >0.9353</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_23759_row15_col0" class="data row15 col0" >0.9492</td>
#       <td id="T_23759_row15_col1" class="data row15 col1" >0.9524</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_23759_row16_col0" class="data row16 col0" >0.9497</td>
#       <td id="T_23759_row16_col1" class="data row16 col1" >0.9464</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_23759_row17_col0" class="data row17 col0" >0.9500</td>
#       <td id="T_23759_row17_col1" class="data row17 col1" >0.9445</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_23759_row18_col0" class="data row18 col0" >0.9491</td>
#       <td id="T_23759_row18_col1" class="data row18 col1" >0.9310</td>
#     </tr>
#     <tr>
#       <th id="T_23759_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_23759_row19_col0" class="data row19 col0" >0.9439</td>
#       <td id="T_23759_row19_col1" class="data row19 col1" >0.9444</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Display accuracies of KNN and DNN in Sequence and Parallel

# %%
# Create a DataFrame
df_combined = pd.DataFrame({
    'KNN': knn_accuracies,
    'DNN': dnn_accuracies,
    'KNN_Parallel': knn_results,
    'DNN_Parallel': dnn_results
})

# Add epoch column
df_combined['Epoch'] = range(1, len(knn_accuracies) + 1)

# Set epoch as index
df_combined.set_index('Epoch', inplace=True)

# Apply styling to the DataFrame
styled_df_combined = df_combined.style \
    .format('{:.4f}') \
    .background_gradient(cmap='Blues')

# Display the styled DataFrame
styled_df_combined
# Out:
# <style type="text/css">
# #T_b0cad_row0_col0, #T_b0cad_row1_col0, #T_b0cad_row1_col1, #T_b0cad_row2_col0, #T_b0cad_row3_col0, #T_b0cad_row4_col0, #T_b0cad_row5_col0, #T_b0cad_row6_col0, #T_b0cad_row7_col0, #T_b0cad_row8_col0, #T_b0cad_row8_col3, #T_b0cad_row9_col0, #T_b0cad_row10_col0, #T_b0cad_row11_col0, #T_b0cad_row12_col0, #T_b0cad_row13_col0, #T_b0cad_row13_col2, #T_b0cad_row14_col0, #T_b0cad_row15_col0, #T_b0cad_row16_col0, #T_b0cad_row17_col0, #T_b0cad_row18_col0, #T_b0cad_row19_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b0cad_row0_col1, #T_b0cad_row8_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b0cad_row0_col2 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_b0cad_row0_col3 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_b0cad_row1_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b0cad_row1_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_b0cad_row2_col1, #T_b0cad_row9_col2 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_b0cad_row2_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_b0cad_row2_col3, #T_b0cad_row5_col2, #T_b0cad_row7_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_b0cad_row3_col1, #T_b0cad_row14_col2, #T_b0cad_row15_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b0cad_row3_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_b0cad_row3_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_b0cad_row4_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_b0cad_row4_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_b0cad_row4_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b0cad_row5_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b0cad_row5_col3 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b0cad_row6_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b0cad_row6_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_b0cad_row6_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_b0cad_row7_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_b0cad_row7_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_b0cad_row8_col2 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_b0cad_row9_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b0cad_row9_col3, #T_b0cad_row18_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b0cad_row10_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_b0cad_row10_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b0cad_row10_col3, #T_b0cad_row11_col3 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_b0cad_row11_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b0cad_row11_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_b0cad_row12_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_b0cad_row12_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_b0cad_row12_col3 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_b0cad_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b0cad_row13_col3, #T_b0cad_row16_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_b0cad_row14_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b0cad_row14_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_b0cad_row15_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_b0cad_row15_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_b0cad_row16_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b0cad_row16_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b0cad_row17_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_b0cad_row17_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_b0cad_row17_col3 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_b0cad_row18_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_b0cad_row18_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_b0cad_row19_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b0cad_row19_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b0cad_row19_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0cad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0cad_level0_col0" class="col_heading level0 col0" >KNN</th>
#       <th id="T_b0cad_level0_col1" class="col_heading level0 col1" >DNN</th>
#       <th id="T_b0cad_level0_col2" class="col_heading level0 col2" >KNN_Parallel</th>
#       <th id="T_b0cad_level0_col3" class="col_heading level0 col3" >DNN_Parallel</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Epoch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0cad_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b0cad_row0_col0" class="data row0 col0" >0.9903</td>
#       <td id="T_b0cad_row0_col1" class="data row0 col1" >0.9525</td>
#       <td id="T_b0cad_row0_col2" class="data row0 col2" >0.9492</td>
#       <td id="T_b0cad_row0_col3" class="data row0 col3" >0.9439</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b0cad_row1_col0" class="data row1 col0" >0.9903</td>
#       <td id="T_b0cad_row1_col1" class="data row1 col1" >0.9511</td>
#       <td id="T_b0cad_row1_col2" class="data row1 col2" >0.9429</td>
#       <td id="T_b0cad_row1_col3" class="data row1 col3" >0.9435</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b0cad_row2_col0" class="data row2 col0" >0.9903</td>
#       <td id="T_b0cad_row2_col1" class="data row2 col1" >0.9571</td>
#       <td id="T_b0cad_row2_col2" class="data row2 col2" >0.9480</td>
#       <td id="T_b0cad_row2_col3" class="data row2 col3" >0.9360</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b0cad_row3_col0" class="data row3 col0" >0.9903</td>
#       <td id="T_b0cad_row3_col1" class="data row3 col1" >0.9663</td>
#       <td id="T_b0cad_row3_col2" class="data row3 col2" >0.9468</td>
#       <td id="T_b0cad_row3_col3" class="data row3 col3" >0.9342</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b0cad_row4_col0" class="data row4 col0" >0.9903</td>
#       <td id="T_b0cad_row4_col1" class="data row4 col1" >0.9588</td>
#       <td id="T_b0cad_row4_col2" class="data row4 col2" >0.9456</td>
#       <td id="T_b0cad_row4_col3" class="data row4 col3" >0.9412</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b0cad_row5_col0" class="data row5 col0" >0.9903</td>
#       <td id="T_b0cad_row5_col1" class="data row5 col1" >0.9597</td>
#       <td id="T_b0cad_row5_col2" class="data row5 col2" >0.9474</td>
#       <td id="T_b0cad_row5_col3" class="data row5 col3" >0.9436</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b0cad_row6_col0" class="data row6 col0" >0.9903</td>
#       <td id="T_b0cad_row6_col1" class="data row6 col1" >0.9576</td>
#       <td id="T_b0cad_row6_col2" class="data row6 col2" >0.9498</td>
#       <td id="T_b0cad_row6_col3" class="data row6 col3" >0.9453</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b0cad_row7_col0" class="data row7 col0" >0.9903</td>
#       <td id="T_b0cad_row7_col1" class="data row7 col1" >0.9594</td>
#       <td id="T_b0cad_row7_col2" class="data row7 col2" >0.9448</td>
#       <td id="T_b0cad_row7_col3" class="data row7 col3" >0.9402</td>
#     </tr>
#     <tr>
#       <th id="T_b0cad_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b0cad_row8_col0" class="data row8 col0" >0.9903</td>
#       <td id="T_b0cad_row8_col1" class="data row8 col1" >0.9525</td>
#       <td id="T_b0c
